# %%
import math
num = 6
factorial = math.factorial(num)
print(" The factorial of", num , "is" , factorial)
# Out:
#  The factorial of 6 is 720

# %%
5+3.0
# Out:
# 8.0

# %%
2*3
# Out:
# 6

# %%
import math
numbers = [1,2,3,4,5]
total = sum(numbers)
print("Sum of given list of numbers is:", total)
average =total/len(numbers)
print("Average of the list of numbers is:", average)
# Out:
# Sum of given list of numbers is: 15
# Average of the list of numbers is: 3.0
